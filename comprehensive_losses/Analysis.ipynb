# %%
#!pip install matplotlib
#!pip install pandas

import matplotlib.pyplot as plt
import pandas as pd

# %%
df_comprehensive_loss = pd.read_csv('maml_comprehensive_losses.csv')
df_comprehensive_loss_train = df_comprehensive_loss[df_comprehensive_loss['phase'] == 'train']

# %%
df_comprehensive_loss_train
# Out:
#         epoch  task_id  phase  support_loss_0  support_accuracy_0  \
# 0           0        0  train        1.966157                0.24
# 1           0        1  train        2.043277                0.20
# 2           0        0  train        2.375950                0.24
# 3           0        1  train        2.772082                0.08
# 4           0        0  train        2.604156                0.20
# ...       ...      ...    ...             ...                 ...
# 159395     99        1  train        8.585500                0.20
# 159396     99        0  train        8.501615                0.20
# 159397     99        1  train        8.661407                0.20
# 159398     99        0  train        8.937901                0.20
# 159399     99        1  train        8.834736                0.20
#
#         support_loss_1  support_accuracy_1  support_loss_2  \
# 0            11.485785                0.20       17.512466
# 1             5.761746                0.44       12.346976
# 2            13.134090                0.20       15.995156
# 3             9.764573                0.32       14.006648
# 4            12.826275                0.20       14.363945
# ...                ...                 ...             ...
# 159395        6.291109                0.20        3.145692
# 159396        6.337976                0.20        3.010175
# 159397        6.733106                0.20        3.172679
# 159398        6.854787                0.20        3.508260
# 159399        6.646648                0.20        3.201501
#
#         support_accuracy_2  support_loss_3  support_accuracy_3  \
# 0                     0.32        9.939052                0.32
# 1                     0.24        9.693971                0.40
# 2                     0.24       14.389878                0.52
# 3                     0.20       10.550004                0.36
# 4                     0.24       11.594155                0.36
# ...                    ...             ...                 ...
# 159395                0.40        0.476710                0.84
# 159396                0.32        0.792362                0.64
# 159397                0.36        1.080620                0.56
# 159398                0.36        0.723153                0.76
# 159399                0.40        0.819449                0.72
#
#         support_loss_4  support_accuracy_4  target_loss_4  target_accuracy_4
# 0             5.861351                0.40       7.011090           0.226667
# 1             7.859974                0.28      12.992436           0.253333
# 2             6.410760                0.40       6.983311           0.306667
# 3            10.754470                0.20      16.359549           0.240000
# 4             8.155646                0.32       9.580047           0.280000
# ...                ...                 ...            ...                ...
# 159395        0.134872                1.00       0.741920           0.666667
# 159396        0.212296                0.96       0.664312           0.720000
# 159397        0.169743                1.00       0.692771           0.720000
# 159398        0.124544                1.00       0.762372           0.746667
# 159399        0.090878                1.00       0.831164           0.706667
#
# [100000 rows x 15 columns]

# %%
df_comprehensive_loss_train[['support_accuracy_4', 'target_accuracy_4']].plot(
    xlabel='x',
    ylabel='acc',
    title='(Inner-loop training) Support VS target'
)

plt.show()

# %%
df_comprehensive_loss_val
# Out:
#         epoch  task_id phase  support_loss_0  support_accuracy_0  \
# 1000        0        0   val       10.388086                 0.2
# 1001        0        1   val       10.215664                 0.2
# 1002        0        0   val       11.196963                 0.2
# 1003        0        1   val       10.521063                 0.2
# 1004        0        0   val       10.775474                 0.2
# ...       ...      ...   ...             ...                 ...
# 162995     99        1   val        8.539978                 0.2
# 162996     99        0   val        8.715943                 0.2
# 162997     99        1   val        8.340522                 0.2
# 162998     99        0   val        9.115469                 0.2
# 162999     99        1   val        7.307397                 0.2
#
#         support_loss_1  support_accuracy_1  support_loss_2  \
# 1000          5.696470                0.24        4.208721
# 1001          6.238200                0.32        4.769479
# 1002          6.482822                0.32        5.401987
# 1003          5.420040                0.44        4.643248
# 1004          6.215370                0.24        4.412137
# ...                ...                 ...             ...
# 162995        6.664664                0.20        3.461724
# 162996        6.913739                0.20        3.948879
# 162997        6.791082                0.20        3.678452
# 162998        6.844466                0.20        3.273390
# 162999        5.997039                0.20        2.642797
#
#         support_accuracy_2  support_loss_3  support_accuracy_3  \
# 1000                  0.28        2.760586                0.36
# 1001                  0.28        1.352798                0.52
# 1002                  0.32        4.311317                0.40
# 1003                  0.44        1.702445                0.56
# 1004                  0.40        3.252676                0.32
# ...                    ...             ...                 ...
# 162995                0.36        1.038190                0.52
# 162996                0.32        0.431435                0.80
# 162997                0.40        0.727927                0.72
# 162998                0.44        1.149226                0.52
# 162999                0.36        0.447287                0.76
#
#         support_loss_4  support_accuracy_4  target_loss_4  target_accuracy_4
# 1000          1.928716                0.36       2.528138           0.333333
# 1001          1.583888                0.48       2.508597           0.240000
# 1002          1.257718                0.40       2.864249           0.226667
# 1003          1.280855                0.48       3.904500           0.346667
# 1004          2.150182                0.52       3.288969           0.186667
# ...                ...                 ...            ...                ...
# 162995        0.124598                1.00       0.671481           0.706667
# 162996        0.201837                0.88       1.011689           0.626667
# 162997        0.137090                1.00       0.691265           0.706667
# 162998        0.416921                0.84       0.895483           0.626667
# 162999        0.133867                1.00       1.073240           0.600000
#
# [63000 rows x 15 columns]

# %%
df_comprehensive_loss_val = df[df_comprehensive_loss['phase'] == 'val']

df_comprehensive_loss_val[['support_accuracy_4', 'target_accuracy_4']].plot(
    xlabel='x',
    ylabel='acc',
    title='(Inner-loop validation) Support VS target'
)

plt.show()

# %%
df_summary_statistics = pd.read_csv('maml_summary_statistics.csv')

df_summary_statistics[['epoch','train_loss_mean', 'val_loss_mean']].plot(
    x = 'epoch',
    xlabel='epoch',
    ylabel='loss',
    title='(outer-loop) train_loss_mean VS val_loss_mean'
)

plt.show()

# %%
df_summary_statistics[['epoch','train_accuracy_mean', 'val_accuracy_mean']].plot(
    x = 'epoch',
    xlabel='x',
    ylabel='epoch',
    title='(outer-loop) train_accuracy_mean VS val_accuracy_mean'
)

plt.show()
