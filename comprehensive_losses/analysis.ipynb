# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv = pd.read_csv("MAML_Curriculum_standardization.csv")

# %%
A = csv.loc[csv.phase=='train']

# %%
A.plot(y=['curriculum_loss4'])
# Out:
# <AxesSubplot:>

# %%
A.plot(y=['support_accuracy_4'])
# Out:
# <AxesSubplot:>

# %%
A.plot(y=['target_accuracy_4'])
# Out:
# <AxesSubplot:>

# %%
A.plot(y=['support_loss_4'])
# Out:
# <AxesSubplot:>

# %%
A.plot(y=['dropout_losses'])
# Out:
# <AxesSubplot:>

# %%
A.plot(y=['weight_layer_10'])
# Out:
# <AxesSubplot:>

# %%
A.plot(y=['gradient_layer_6'])
# Out:
# <AxesSubplot:>

# %%
A.plot(y=['target_loss_4'])
# Out:
# <AxesSubplot:>
