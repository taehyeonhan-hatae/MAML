# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
norm_info = pd.read_csv('../MAML_JM/MAML_filter48_inner_loop.csv')

# %%
norm_info_train= norm_info[norm_info['phase']=='train']
norm_info_val= norm_info[norm_info['phase']=='val']
norm_info_test= norm_info[norm_info['current_iter']=='test']

# %%
per_inner_loop_step = norm_info_train.groupby('num_step').mean()
per_inner_loop_step
# Out:
#           layer_dict.conv0.conv.weight_grad_mean  \
# num_step
# 0                                       0.043085
# 1                                      -0.004372
# 2                                      -0.001824
# 3                                      -0.001010
# 4                                      -0.000130
#
#           layer_dict.conv0.conv.weight_grad_L1norm  \
# num_step
# 0                                       233.009425
# 1                                        93.808149
# 2                                        62.612453
# 3                                        33.718355
# 4                                        14.805069
#
#           layer_dict.conv0.conv.weight_grad_L2norm  \
# num_step
# 0                                        10.464057
# 1                                         4.220881
# 2                                         2.718250
# 3                                         1.440902
# 4                                         0.633651
#
#           layer_dict.conv0.conv.weight_weight_mean  \
# num_step
# 0                                         0.002414
# 1                                         0.001983
# 2                                         0.002027
# 3                                         0.002045
# 4                                         0.002055
#
#           layer_dict.conv0.conv.weight_weight_L1norm  \
# num_step
# 0                                         200.898813
# 1                                         200.895209
# 2                                         200.896431
# 3                                         200.895806
# 4                                         200.897091
#
#           layer_dict.conv0.conv.weight_weight_L2norm  \
# num_step
# 0                                           7.149253
# 1                                           7.150121
# 2                                           7.150280
# 3                                           7.150340
# 4                                           7.150359
#
#           layer_dict.conv0.conv.bias_grad_mean  \
# num_step
# 0                                 1.513969e-09
# 1                                 5.076921e-10
# 2                                 3.333242e-10
# 3                                -1.425609e-11
# 4                                -7.262760e-12
#
#           layer_dict.conv0.conv.bias_grad_L1norm  \
# num_step
# 0                                   1.856326e-06
# 1                                   1.159096e-06
# 2                                   8.701068e-07
# 3                                   3.472077e-07
# 4                                   1.485857e-07
#
#           layer_dict.conv0.conv.bias_grad_L2norm  \
# num_step
# 0                                   4.175098e-07
# 1                                   2.602160e-07
# 2                                   1.965700e-07
# 3                                   7.788988e-08
# 4                                   3.298814e-08
#
#           layer_dict.conv0.conv.bias_weight_mean  ...  \
# num_step                                          ...
# 0                                      -0.007349  ...
# 1                                      -0.007349  ...
# 2                                      -0.007349  ...
# 3                                      -0.007349  ...
# 4                                      -0.007349  ...
#
#           layer_dict.linear.weights_grad_L2norm  \
# num_step
# 0                                     35.203853
# 1                                     33.020195
# 2                                     24.772486
# 3                                      9.510222
# 4                                      2.991181
#
#           layer_dict.linear.weights_weight_mean  \
# num_step
# 0                                     -0.004471
# 1                                     -0.004471
# 2                                     -0.004471
# 3                                     -0.004471
# 4                                     -0.004471
#
#           layer_dict.linear.weights_weight_L1norm  \
# num_step
# 0                                      429.754279
# 1                                      427.212701
# 2                                      427.335783
# 3                                      427.933652
# 4                                      428.013713
#
#           layer_dict.linear.weights_weight_L2norm  \
# num_step
# 0                                        9.924366
# 1                                        9.910973
# 2                                        9.911572
# 3                                        9.913787
# 4                                        9.914398
#
#           layer_dict.linear.bias_grad_mean  \
# num_step
# 0                             3.815447e-09
# 1                             1.143329e-09
# 2                             1.083317e-09
# 3                             9.193480e-10
# 4                             9.461946e-10
#
#           layer_dict.linear.bias_grad_L1norm  \
# num_step
# 0                                   1.543510
# 1                                   1.465660
# 2                                   1.108306
# 3                                   0.397624
# 4                                   0.113697
#
#           layer_dict.linear.bias_grad_L2norm  \
# num_step
# 0                                   0.862434
# 1                                   0.819745
# 2                                   0.622501
# 3                                   0.213038
# 4                                   0.061582
#
#           layer_dict.linear.bias_weight_mean  \
# num_step
# 0                                   0.001392
# 1                                   0.001392
# 2                                   0.001392
# 3                                   0.001392
# 4                                   0.001392
#
#           layer_dict.linear.bias_weight_L1norm  \
# num_step
# 0                                     0.877535
# 1                                     0.868627
# 2                                     0.859421
# 3                                     0.854208
# 4                                     0.856732
#
#           layer_dict.linear.bias_weight_L2norm
# num_step
# 0                                     0.410269
# 1                                     0.406364
# 2                                     0.401622
# 3                                     0.399629
# 4                                     0.400743
#
# [5 rows x 60 columns]

# %%
per_inner_loop_step['layer_dict.linear.weights_grad_L2norm']
# Out:
# num_step
# 0    35.203853
# 1    33.020195
# 2    24.772486
# 3     9.510222
# 4     2.991181
# Name: layer_dict.linear.weights_grad_L2norm, dtype: float64

# %%
per_inner_loop_step['layer_dict.linear.weights_weight_L2norm']
# Out:
# num_step
# 0    9.924366
# 1    9.910973
# 2    9.911572
# 3    9.913787
# 4    9.914398
# Name: layer_dict.linear.weights_weight_L2norm, dtype: float64

# %%
per_inner_loop_step['layer_dict.conv3.conv.weight_grad_L2norm']
# Out:
# num_step
# 0    2.048292
# 1    1.136970
# 2    0.838089
# 3    0.445826
# 4    0.189935
# Name: layer_dict.conv3.conv.weight_grad_L2norm, dtype: float64

# %%
per_inner_loop_step['layer_dict.conv3.conv.weight_weight_L2norm']
# Out:
# num_step
# 0    25.982990
# 1    25.983000
# 2    25.983004
# 3    25.983005
# 4    25.983006
# Name: layer_dict.conv3.conv.weight_weight_L2norm, dtype: float64

# %%
specific_column_values = norm_info_train[norm_info_train['num_step'] == 0]
specific_column_values
# Out:
#         current_iter  phase  num_step  layer_dict.conv0.conv.weight_grad_mean  \
# 0                  0  train         0                                0.013776
# 5                  0  train         0                                0.003947
# 10                 1  train         0                               -0.018747
# 15                 1  train         0                                0.002656
# 20                 2  train         0                               -0.066766
# ...              ...    ...       ...                                     ...
# 1196975        74997  train         0                                0.052178
# 1196980        74998  train         0                                0.119234
# 1196985        74998  train         0                                0.093023
# 1196990        74999  train         0                                0.096749
# 1196995        74999  train         0                                0.078273
#
#          layer_dict.conv0.conv.weight_grad_L1norm  \
# 0                                      238.842377
# 5                                      237.155334
# 10                                     207.459351
# 15                                     251.496613
# 20                                     215.855316
# ...                                           ...
# 1196975                                298.032196
# 1196980                                329.830566
# 1196985                                358.824310
# 1196990                                302.861328
# 1196995                                237.994202
#
#          layer_dict.conv0.conv.weight_grad_L2norm  \
# 0                                       10.310259
# 5                                       10.745303
# 10                                       8.741799
# 15                                       9.755734
# 20                                       9.951371
# ...                                           ...
# 1196975                                 13.708746
# 1196980                                 15.614138
# 1196985                                 16.311543
# 1196990                                 13.785777
# 1196995                                 11.419952
#
#          layer_dict.conv0.conv.weight_weight_mean  \
# 0                                       -0.001755
# 5                                       -0.001755
# 10                                      -0.001789
# 15                                      -0.001789
# 20                                      -0.001847
# ...                                           ...
# 1196975                                  0.004371
# 1196980                                  0.004386
# 1196985                                  0.004386
# 1196990                                  0.004389
# 1196995                                  0.004389
#
#          layer_dict.conv0.conv.weight_weight_L1norm  \
# 0                                         75.456955
# 5                                         75.456955
# 10                                        75.426865
# 15                                        75.426865
# 20                                        75.425079
# ...                                             ...
# 1196975                                  293.123322
# 1196980                                  293.125610
# 1196985                                  293.125610
# 1196990                                  293.132629
# 1196995                                  293.132629
#
#          layer_dict.conv0.conv.weight_weight_L2norm  \
# 0                                          2.396668
# 5                                          2.396668
# 10                                         2.396444
# 15                                         2.396444
# 20                                         2.396496
# ...                                             ...
# 1196975                                   10.494678
# 1196980                                   10.494707
# 1196985                                   10.494707
# 1196990                                   10.494815
# 1196995                                   10.494815
#
#          layer_dict.conv0.conv.bias_grad_mean  ...  \
# 0                                5.349284e-08  ...
# 5                                5.347344e-08  ...
# 10                               3.442013e-08  ...
# 15                               3.919316e-08  ...
# 20                              -7.140140e-08  ...
# ...                                       ...  ...
# 1196975                         -1.209143e-08  ...
# 1196980                         -8.257000e-09  ...
# 1196985                          5.529728e-09  ...
# 1196990                         -9.502401e-09  ...
# 1196995                          8.925175e-10  ...
#
#          layer_dict.linear.weights_grad_L2norm  \
# 0                                    10.609147
# 5                                     8.282177
# 10                                    9.011809
# 15                                    9.453609
# 20                                    7.907076
# ...                                        ...
# 1196975                              40.460262
# 1196980                              39.713799
# 1196985                              40.007584
# 1196990                              40.280190
# 1196995                              41.319286
#
#          layer_dict.linear.weights_weight_mean  \
# 0                                    -0.000305
# 5                                    -0.000305
# 10                                   -0.000313
# 15                                   -0.000313
# 20                                   -0.000312
# ...                                        ...
# 1196975                              -0.008891
# 1196980                              -0.008894
# 1196985                              -0.008894
# 1196990                              -0.008895
# 1196995                              -0.008895
#
#          layer_dict.linear.weights_weight_L1norm  \
# 0                                     211.514740
# 5                                     211.514740
# 10                                    211.356628
# 15                                    211.356628
# 20                                    211.217072
# ...                                          ...
# 1196975                               839.701904
# 1196980                               839.652710
# 1196985                               839.652710
# 1196990                               839.625122
# 1196995                               839.625122
#
#          layer_dict.linear.weights_weight_L2norm  \
# 0                                       3.152209
# 5                                       3.152209
# 10                                      3.150295
# 15                                      3.150295
# 20                                      3.148381
# ...                                          ...
# 1196975                                20.610863
# 1196980                                20.611046
# 1196985                                20.611046
# 1196990                                20.611389
# 1196995                                20.611389
#
#          layer_dict.linear.bias_grad_mean  layer_dict.linear.bias_grad_L1norm  \
# 0                            1.490116e-09                            0.498336
# 5                            5.960465e-09                            0.428868
# 10                           2.980232e-09                            0.448557
# 15                           8.940697e-09                            0.421058
# 20                           2.980232e-09                            0.436457
# ...                                   ...                                 ...
# 1196975                     -5.960465e-09                            1.599931
# 1196980                      1.192093e-08                            1.599923
# 1196985                      0.000000e+00                            1.599884
# 1196990                      1.788139e-08                            1.599924
# 1196995                      0.000000e+00                            1.599924
#
#          layer_dict.linear.bias_grad_L2norm  \
# 0                                  0.275611
# 5                                  0.228195
# 10                                 0.220851
# 15                                 0.236031
# 20                                 0.237844
# ...                                     ...
# 1196975                            0.894389
# 1196980                            0.894384
# 1196985                            0.894362
# 1196990                            0.894385
# 1196995                            0.894385
#
#          layer_dict.linear.bias_weight_mean  \
# 0                                  0.000000
# 5                                  0.000000
# 10                                -0.000200
# 15                                -0.000200
# 20                                -0.000089
# ...                                     ...
# 1196975                            0.002749
# 1196980                            0.002754
# 1196985                            0.002754
# 1196990                            0.002754
# 1196995                            0.002754
#
#          layer_dict.linear.bias_weight_L1norm  \
# 0                                    0.000000
# 5                                    0.000000
# 10                                   0.005000
# 15                                   0.005000
# 20                                   0.007333
# ...                                       ...
# 1196975                              1.417742
# 1196980                              1.417060
# 1196985                              1.417060
# 1196990                              1.416499
# 1196995                              1.416499
#
#          layer_dict.linear.bias_weight_L2norm
# 0                                    0.000000
# 5                                    0.000000
# 10                                   0.002236
# 15                                   0.002236
# 20                                   0.003512
# ...                                       ...
# 1196975                              0.650737
# 1196980                              0.650440
# 1196985                              0.650440
# 1196990                              0.650205
# 1196995                              0.650205
#
# [150000 rows x 63 columns]

# %%
gr = specific_column_values.groupby('current_iter').mean()

# %%
# 그래프를 그릴 컬럼들의 리스트
columns_to_plot = ['layer_dict.conv0.conv.weight_grad_L2norm', 
                   'layer_dict.conv1.conv.weight_grad_L2norm', 
                   'layer_dict.conv2.conv.weight_grad_L2norm',
                   'layer_dict.conv3.conv.weight_grad_L2norm',
                   'layer_dict.linear.weights_grad_L2norm']

columns_to_plot_label = ['conv1_w', 'conv2_w', 'conv3_w', 'conv4_w', 'classifier']

# 특정 열(Column)의 값을 그래프로 그리기
plt.figure(figsize=(10, 6))  # 그래프의 크기 설정 

plt.plot(gr[columns_to_plot].values, label=columns_to_plot_label)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), shadow=False, ncol=len(columns_to_plot))  # 범례 추가
plt.xlabel('Iteration')  # X 축 라벨 설정
plt.ylabel('Gradient Norm (log scale)')  

plt.yscale('log')  # Y 축을 로그 스케일로 변경
plt.ylim(10 ** -2, 10 **2)

plt.show()  # 그래프 보여주기

# %%
 # 그래프를 그릴 컬럼들의 리스트
columns_to_plot = [ 'layer_dict.conv0.conv.weight_weight_L2norm', 
                    'layer_dict.conv1.conv.weight_weight_L2norm', 
                    'layer_dict.conv2.conv.weight_weight_L2norm',
                    'layer_dict.conv3.conv.weight_weight_L2norm',
                    'layer_dict.linear.weights_weight_L2norm']
columns_to_plot_label = ['conv1_w', 'conv2_w', 'conv3_w', 'conv4_w', 'classifier']

# 특정 열(Column)의 값을 그래프로 그리기
plt.figure(figsize=(10, 6))  # 그래프의 크기 설정 

plt.plot(gr[columns_to_plot].values, label=columns_to_plot_label)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), shadow=False, ncol=len(columns_to_plot))  # 범례 추가
plt.ylabel('weight l2_norm')  

plt.show()  # 그래프 보여주기

# %%
 # 그래프를 그릴 컬럼들의 리스트
columns_to_plot = [ #'layer_dict.conv0.conv.weight_grad_mean', 
                    'layer_dict.conv1.conv.weight_grad_mean', 
                    'layer_dict.conv2.conv.weight_grad_mean',
                    'layer_dict.conv3.conv.weight_grad_mean',
                    'layer_dict.linear.weights_grad_mean']
columns_to_plot_label = [#'conv1_w', 
                         'conv2_w', 
                         'conv3_w', 
                         'conv4_w', 
                         'classifier']

# 특정 열(Column)의 값을 그래프로 그리기
plt.figure(figsize=(10, 6))  # 그래프의 크기 설정 

plt.plot(gr[columns_to_plot].values, label=columns_to_plot_label)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), shadow=False, ncol=len(columns_to_plot))  # 범례 추가
plt.ylabel('Grad mean')  

# plt.yscale('log')  # Y 축을 로그 스케일로 변경
# plt.ylim(10 ** -5, 10 **2)

plt.show()  # 그래프 보여주기

# %%
 # 그래프를 그릴 컬럼들의 리스트
columns_to_plot = [ 'layer_dict.conv0.conv.weight_weight_mean', 
                    'layer_dict.conv1.conv.weight_weight_mean', 
                    'layer_dict.conv2.conv.weight_weight_mean',
                    'layer_dict.conv3.conv.weight_weight_mean',
                    'layer_dict.linear.weights_weight_mean']
columns_to_plot_label = ['conv1_w', 
                         'conv2_w', 
                         'conv3_w', 
                         'conv4_w', 
                         'classifier']

# 특정 열(Column)의 값을 그래프로 그리기
plt.figure(figsize=(10, 6))  # 그래프의 크기 설정 

plt.plot(gr[columns_to_plot].values, label=columns_to_plot_label)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), shadow=False, ncol=len(columns_to_plot))  # 범례 추가
plt.ylabel('weight mean')  

# plt.yscale('log')  # Y 축을 로그 스케일로 변경
# plt.ylim(10 ** -5, 10 **2)

plt.show()  # 그래프 보여주기
