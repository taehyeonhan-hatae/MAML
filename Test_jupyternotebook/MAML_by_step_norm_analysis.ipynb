# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
norm_info = pd.read_csv('../MAML_JM/MAML_filter48_inner_loop.csv')
# Out:
# C:\Users\JM\anaconda3\envs\metal\lib\site-packages\IPython\core\interactiveshell.py:3553: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
norm_info_train= norm_info[norm_info['phase']=='train']
norm_info_val= norm_info[norm_info['phase']=='val']
norm_info_test= norm_info[norm_info['current_iter']=='test']

# %%
per_inner_loop_step = norm_info_train.groupby('num_step').mean()
per_inner_loop_step
# Out:
#           layer_dict.conv0.conv.weight_grad_mean  \
# num_step
# 0                                      -0.003789
# 1                                      -0.001921
# 2                                      -0.001850
# 3                                       0.000500
# 4                                       0.000234
#
#           layer_dict.conv0.conv.weight_grad_L1norm  \
# num_step
# 0                                       191.048759
# 1                                        80.161840
# 2                                        69.033307
# 3                                        34.512854
# 4                                        15.959513
#
#           layer_dict.conv0.conv.weight_grad_L2norm  \
# num_step
# 0                                         8.827264
# 1                                         3.595049
# 2                                         3.096055
# 3                                         1.481111
# 4                                         0.685384
#
#           layer_dict.conv0.conv.weight_weight_mean  \
# num_step
# 0                                        -0.000394
# 1                                        -0.000356
# 2                                        -0.000337
# 3                                        -0.000319
# 4                                        -0.000324
#
#           layer_dict.conv0.conv.weight_weight_L1norm  \
# num_step
# 0                                         174.801584
# 1                                         174.814197
# 2                                         174.815310
# 3                                         174.819620
# 4                                         174.819821
#
#           layer_dict.conv0.conv.weight_weight_L2norm  \
# num_step
# 0                                           6.230970
# 1                                           6.231638
# 2                                           6.231753
# 3                                           6.231842
# 4                                           6.231864
#
#           layer_dict.conv0.conv.bias_grad_mean  \
# num_step
# 0                                 1.438490e-09
# 1                                 3.699350e-10
# 2                                 4.536852e-10
# 3                                -3.837870e-11
# 4                                -1.860727e-11
#
#           layer_dict.conv0.conv.bias_grad_L1norm  \
# num_step
# 0                                   1.612249e-06
# 1                                   1.024031e-06
# 2                                   8.301890e-07
# 3                                   3.325671e-07
# 4                                   1.593268e-07
#
#           layer_dict.conv0.conv.bias_grad_L2norm  \
# num_step
# 0                                   3.652442e-07
# 1                                   2.313190e-07
# 2                                   1.889034e-07
# 3                                   7.501349e-08
# 4                                   3.537752e-08
#
#           layer_dict.conv0.conv.bias_weight_mean  ...  \
# num_step                                          ...
# 0                                      -0.018742  ...
# 1                                      -0.018742  ...
# 2                                      -0.018742  ...
# 3                                      -0.018742  ...
# 4                                      -0.018742  ...
#
#           layer_dict.linear.weights_grad_L2norm  \
# num_step
# 0                                     33.512125
# 1                                     31.359454
# 2                                     24.546513
# 3                                      9.386623
# 4                                      3.171186
#
#           layer_dict.linear.weights_weight_mean  \
# num_step
# 0                                     -0.001515
# 1                                     -0.001515
# 2                                     -0.001515
# 3                                     -0.001515
# 4                                     -0.001515
#
#           layer_dict.linear.weights_weight_L1norm  \
# num_step
# 0                                      259.816443
# 1                                      257.668690
# 2                                      257.713846
# 3                                      258.244232
# 4                                      258.333578
#
#           layer_dict.linear.weights_weight_L2norm  \
# num_step
# 0                                        5.586256
# 1                                        5.571093
# 2                                        5.571452
# 3                                        5.575341
# 4                                        5.576196
#
#           layer_dict.linear.bias_grad_mean  \
# num_step
# 0                             3.401234e-09
# 1                             7.872586e-10
# 2                             1.062654e-09
# 3                             9.044073e-10
# 4                             9.255361e-10
#
#           layer_dict.linear.bias_grad_L1norm  \
# num_step
# 0                                   1.511723
# 1                                   1.420630
# 2                                   1.123522
# 3                                   0.396713
# 4                                   0.120792
#
#           layer_dict.linear.bias_grad_L2norm  \
# num_step
# 0                                   0.844744
# 1                                   0.794008
# 2                                   0.630836
# 3                                   0.212728
# 4                                   0.065279
#
#           layer_dict.linear.bias_weight_mean  \
# num_step
# 0                                   0.016385
# 1                                   0.016385
# 2                                   0.016385
# 3                                   0.016385
# 4                                   0.016385
#
#           layer_dict.linear.bias_weight_L1norm  \
# num_step
# 0                                     0.768119
# 1                                     0.757637
# 2                                     0.747752
# 3                                     0.740841
# 4                                     0.744043
#
#           layer_dict.linear.bias_weight_L2norm
# num_step
# 0                                     0.371586
# 1                                     0.368256
# 2                                     0.362855
# 3                                     0.360787
# 4                                     0.362041
#
# [5 rows x 60 columns]

# %%
per_inner_loop_step['layer_dict.linear.weights_grad_L2norm']
# Out:
# num_step
# 0    33.512125
# 1    31.359454
# 2    24.546513
# 3     9.386623
# 4     3.171186
# Name: layer_dict.linear.weights_grad_L2norm, dtype: float64

# %%
per_inner_loop_step['layer_dict.linear.weights_weight_L2norm']
# Out:
# num_step
# 0    5.586256
# 1    5.571093
# 2    5.571452
# 3    5.575341
# 4    5.576196
# Name: layer_dict.linear.weights_weight_L2norm, dtype: float64

# %%
per_inner_loop_step['layer_dict.conv3.conv.weight_grad_L2norm']
# Out:
# num_step
# 0    2.105958
# 1    1.142359
# 2    1.026975
# 3    0.512035
# 4    0.228644
# Name: layer_dict.conv3.conv.weight_grad_L2norm, dtype: float64

# %%
per_inner_loop_step['layer_dict.conv3.conv.weight_weight_L2norm']
# Out:
# num_step
# 0    21.058225
# 1    21.058237
# 2    21.058241
# 3    21.058244
# 4    21.058245
# Name: layer_dict.conv3.conv.weight_weight_L2norm, dtype: float64

# %%
specific_column_values = norm_info_train[norm_info_train['num_step'] == 0]
specific_column_values
# Out:
#        current_iter  phase  num_step  layer_dict.conv0.conv.weight_grad_mean  \
# 0                 0  train         0                                0.013776
# 5                 0  train         0                                0.003947
# 10                1  train         0                               -0.035179
# 15                1  train         0                               -0.000191
# 20                2  train         0                               -0.030579
# ...             ...    ...       ...                                     ...
# 796975        49997  train         0                                0.013066
# 796980        49998  train         0                                0.087429
# 796985        49998  train         0                                0.060802
# 796990        49999  train         0                                0.018338
# 796995        49999  train         0                                0.045488
#
#         layer_dict.conv0.conv.weight_grad_L1norm  \
# 0                                     238.842377
# 5                                     237.155319
# 10                                    195.699707
# 15                                    252.793365
# 20                                    208.204697
# ...                                          ...
# 796975                                330.402527
# 796980                                301.103607
# 796985                                444.069580
# 796990                                269.829285
# 796995                                263.835571
#
#         layer_dict.conv0.conv.weight_grad_L2norm  \
# 0                                      10.310260
# 5                                      10.745303
# 10                                      8.427951
# 15                                      9.654286
# 20                                      8.651752
# ...                                          ...
# 796975                                 14.469161
# 796980                                 14.006538
# 796985                                 19.916897
# 796990                                 11.755573
# 796995                                 11.396485
#
#         layer_dict.conv0.conv.weight_weight_mean  \
# 0                                      -0.001755
# 5                                      -0.001755
# 10                                     -0.001787
# 15                                     -0.001787
# 20                                     -0.001779
# ...                                          ...
# 796975                                 -0.000512
# 796980                                 -0.000533
# 796985                                 -0.000533
# 796990                                 -0.000551
# 796995                                 -0.000551
#
#         layer_dict.conv0.conv.weight_weight_L1norm  \
# 0                                        75.456955
# 5                                        75.456955
# 10                                       75.420868
# 15                                       75.420868
# 20                                       75.416893
# ...                                            ...
# 796975                                  246.417404
# 796980                                  246.418930
# 796985                                  246.418930
# 796990                                  246.420532
# 796995                                  246.420532
#
#         layer_dict.conv0.conv.weight_weight_L2norm  \
# 0                                         2.396668
# 5                                         2.396668
# 10                                        2.396077
# 15                                        2.396077
# 20                                        2.396430
# ...                                            ...
# 796975                                    8.852283
# 796980                                    8.852489
# 796985                                    8.852489
# 796990                                    8.852668
# 796995                                    8.852668
#
#         layer_dict.conv0.conv.bias_grad_mean  ...  \
# 0                               4.000807e-08  ...
# 5                               5.372567e-08  ...
# 10                              6.775372e-08  ...
# 15                             -4.844818e-08  ...
# 20                             -8.168476e-09  ...
# ...                                      ...  ...
# 796975                          7.518490e-10  ...
# 796980                          7.797402e-09  ...
# 796985                          3.613726e-10  ...
# 796990                          2.146407e-08  ...
# 796995                          1.027001e-08  ...
#
#         layer_dict.linear.weights_grad_L2norm  \
# 0                                   10.609147
# 5                                    8.282177
# 10                                   8.969696
# 15                                   9.469932
# 20                                   8.022581
# ...                                       ...
# 796975                              38.714523
# 796980                              38.878735
# 796985                              38.082523
# 796990                              37.764782
# 796995                              37.937901
#
#         layer_dict.linear.weights_weight_mean  \
# 0                                   -0.000305
# 5                                   -0.000305
# 10                                  -0.000309
# 15                                  -0.000309
# 20                                  -0.000308
# ...                                       ...
# 796975                              -0.004017
# 796980                              -0.004017
# 796985                              -0.004017
# 796990                              -0.004017
# 796995                              -0.004017
#
#         layer_dict.linear.weights_weight_L1norm  \
# 0                                    211.514740
# 5                                    211.514740
# 10                                   211.388641
# 15                                   211.388641
# 20                                   211.261322
# ...                                         ...
# 796975                               554.501953
# 796980                               554.572266
# 796985                               554.572266
# 796990                               554.650085
# 796995                               554.650085
#
#         layer_dict.linear.weights_weight_L2norm  \
# 0                                      3.152209
# 5                                      3.152209
# 10                                     3.150587
# 15                                     3.150587
# 20                                     3.149065
# ...                                         ...
# 796975                                13.481719
# 796980                                13.483132
# 796985                                13.483132
# 796990                                13.484650
# 796995                                13.484650
#
#         layer_dict.linear.bias_grad_mean  layer_dict.linear.bias_grad_L1norm  \
# 0                           1.490116e-09                            0.498336
# 5                           5.960465e-09                            0.428868
# 10                          2.980232e-09                            0.444988
# 15                          2.980232e-09                            0.421905
# 20                          5.960465e-09                            0.448645
# ...                                  ...                                 ...
# 796975                     -1.192093e-08                            1.599843
# 796980                      1.192093e-08                            1.599843
# 796985                      1.192093e-08                            1.599899
# 796990                      0.000000e+00                            1.599843
# 796995                      1.192093e-08                            1.599836
#
#         layer_dict.linear.bias_grad_L2norm  \
# 0                                 0.275611
# 5                                 0.228195
# 10                                0.221098
# 15                                0.237419
# 20                                0.247847
# ...                                    ...
# 796975                            0.894339
# 796980                            0.894339
# 796985                            0.894371
# 796990                            0.894339
# 796995                            0.894336
#
#         layer_dict.linear.bias_weight_mean  \
# 0                                 0.000000
# 5                                 0.000000
# 10                               -0.000200
# 15                               -0.000200
# 20                               -0.000256
# ...                                    ...
# 796975                            0.023445
# 796980                            0.023448
# 796985                            0.023448
# 796990                            0.023451
# 796995                            0.023451
#
#         layer_dict.linear.bias_weight_L1norm  \
# 0                                   0.000000
# 5                                   0.000000
# 10                                  0.005000
# 15                                  0.005000
# 20                                  0.006660
# ...                                      ...
# 796975                              1.421177
# 796980                              1.421549
# 796985                              1.421549
# 796990                              1.422072
# 796995                              1.422072
#
#         layer_dict.linear.bias_weight_L2norm
# 0                                   0.000000
# 5                                   0.000000
# 10                                  0.002236
# 15                                  0.002236
# 20                                  0.003240
# ...                                      ...
# 796975                              0.668031
# 796980                              0.668185
# 796985                              0.668185
# 796990                              0.668412
# 796995                              0.668412
#
# [100000 rows x 63 columns]

# %%
gr = specific_column_values.groupby('current_iter').mean()

# %%
# 그래프를 그릴 컬럼들의 리스트
columns_to_plot = ['layer_dict.conv0.conv.weight_grad_L2norm', 
                   'layer_dict.conv1.conv.weight_grad_L2norm', 
                   'layer_dict.conv2.conv.weight_grad_L2norm',
                   'layer_dict.conv3.conv.weight_grad_L2norm',
                   'layer_dict.linear.weights_grad_L2norm']

columns_to_plot_label = ['conv1_w', 'conv2_w', 'conv3_w', 'conv4_w', 'classifier']

# 특정 열(Column)의 값을 그래프로 그리기
plt.figure(figsize=(10, 6))  # 그래프의 크기 설정 

plt.plot(gr[columns_to_plot].values, label=columns_to_plot_label)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), shadow=False, ncol=len(columns_to_plot))  # 범례 추가
plt.xlabel('Iteration')  # X 축 라벨 설정
plt.ylabel('Gradient Norm (log scale)')  

plt.yscale('log')  # Y 축을 로그 스케일로 변경
plt.ylim(10 ** -2, 10 **2)

plt.show()  # 그래프 보여주기

# %%
 # 그래프를 그릴 컬럼들의 리스트
columns_to_plot = [ 'layer_dict.conv0.conv.weight_weight_L2norm', 
                    'layer_dict.conv1.conv.weight_weight_L2norm', 
                    'layer_dict.conv2.conv.weight_weight_L2norm',
                    'layer_dict.conv3.conv.weight_weight_L2norm',
                    'layer_dict.linear.weights_weight_L2norm']
columns_to_plot_label = ['conv1_w', 'conv2_w', 'conv3_w', 'conv4_w', 'classifier']

# 특정 열(Column)의 값을 그래프로 그리기
plt.figure(figsize=(10, 6))  # 그래프의 크기 설정 

plt.plot(gr[columns_to_plot].values, label=columns_to_plot_label)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), shadow=False, ncol=len(columns_to_plot))  # 범례 추가
plt.ylabel('weight l2_norm')  

plt.show()  # 그래프 보여주기

# %%
 # 그래프를 그릴 컬럼들의 리스트
columns_to_plot = [ #'layer_dict.conv0.conv.weight_grad_mean', 
                    'layer_dict.conv1.conv.weight_grad_mean', 
                    'layer_dict.conv2.conv.weight_grad_mean',
                    'layer_dict.conv3.conv.weight_grad_mean',
                    'layer_dict.linear.weights_grad_mean']
columns_to_plot_label = [#'conv1_w', 
                         'conv2_w', 
                         'conv3_w', 
                         'conv4_w', 
                         'classifier']

# 특정 열(Column)의 값을 그래프로 그리기
plt.figure(figsize=(10, 6))  # 그래프의 크기 설정 

plt.plot(gr[columns_to_plot].values, label=columns_to_plot_label)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), shadow=False, ncol=len(columns_to_plot))  # 범례 추가
plt.ylabel('Grad mean')  

# plt.yscale('log')  # Y 축을 로그 스케일로 변경
# plt.ylim(10 ** -5, 10 **2)

plt.show()  # 그래프 보여주기

# %%
 # 그래프를 그릴 컬럼들의 리스트
columns_to_plot = [ 'layer_dict.conv0.conv.weight_weight_mean', 
                    'layer_dict.conv1.conv.weight_weight_mean', 
                    'layer_dict.conv2.conv.weight_weight_mean',
                    'layer_dict.conv3.conv.weight_weight_mean',
                    'layer_dict.linear.weights_weight_mean']
columns_to_plot_label = ['conv1_w', 
                         'conv2_w', 
                         'conv3_w', 
                         'conv4_w', 
                         'classifier']

# 특정 열(Column)의 값을 그래프로 그리기
plt.figure(figsize=(10, 6))  # 그래프의 크기 설정 

plt.plot(gr[columns_to_plot].values, label=columns_to_plot_label)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), shadow=False, ncol=len(columns_to_plot))  # 범례 추가
plt.ylabel('weight mean')  

# plt.yscale('log')  # Y 축을 로그 스케일로 변경
# plt.ylim(10 ** -5, 10 **2)

plt.show()  # 그래프 보여주기
