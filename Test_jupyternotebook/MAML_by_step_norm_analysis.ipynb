# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
norm_info = pd.read_csv('../experiment_result/MAML_JM/MAML_JM.csv')
# Out:
# C:\Users\JM\anaconda3\envs\maml\lib\site-packages\IPython\core\interactiveshell.py:3553: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
norm_info_train= norm_info[norm_info['phase']=='train']
norm_info_val= norm_info[norm_info['phase']=='val']
norm_info_test= norm_info[norm_info['current_iter']=='test']

# %%
per_inner_loop_step = norm_info_train.groupby('num_step').mean()
per_inner_loop_step
# Out:
#           layer_dict.conv0.conv.weight_grad_mean  \
# num_step
# 0                                       0.021595
# 1                                      -0.002237
# 2                                      -0.007949
# 3                                       0.001539
# 4                                       0.000352
#
#           layer_dict.conv0.conv.weight_grad_L1norm  \
# num_step
# 0                                       220.981296
# 1                                        76.209986
# 2                                        71.616763
# 3                                        34.649019
# 4                                        15.733991
#
#           layer_dict.conv0.conv.weight_grad_L2norm  \
# num_step
# 0                                         9.856021
# 1                                         3.332791
# 2                                         3.168187
# 3                                         1.478192
# 4                                         0.669120
#
#           layer_dict.conv0.conv.weight_weight_mean  \
# num_step
# 0                                        -0.001655
# 1                                        -0.001633
# 2                                        -0.001553
# 3                                        -0.001569
# 4                                        -0.001572
#
#           layer_dict.conv0.conv.weight_weight_L1norm  \
# num_step
# 0                                         173.269547
# 1                                         173.273074
# 2                                         173.285424
# 3                                         173.283324
# 4                                         173.282978
#
#           layer_dict.conv0.conv.weight_weight_L2norm  \
# num_step
# 0                                           5.967738
# 1                                           5.967842
# 2                                           5.967946
# 3                                           5.967969
# 4                                           5.967975
#
#           layer_dict.conv0.conv.bias_grad_mean  \
# num_step
# 0                                 1.812621e-09
# 1                                 4.433622e-10
# 2                                 5.693263e-10
# 3                                -5.824541e-11
# 4                                -2.280185e-11
#
#           layer_dict.conv0.conv.bias_grad_L1norm  \
# num_step
# 0                                   1.726285e-06
# 1                                   1.095586e-06
# 2                                   8.973387e-07
# 3                                   3.467996e-07
# 4                                   1.638273e-07
#
#           layer_dict.conv0.conv.bias_grad_L2norm  \
# num_step
# 0                                   3.942696e-07
# 1                                   2.501274e-07
# 2                                   2.056305e-07
# 3                                   7.871433e-08
# 4                                   3.659030e-08
#
#           layer_dict.conv0.conv.bias_weight_mean  ...  \
# num_step                                          ...
# 0                                      -0.010689  ...
# 1                                      -0.010689  ...
# 2                                      -0.010689  ...
# 3                                      -0.010689  ...
# 4                                      -0.010689  ...
#
#           layer_dict.linear.weights_grad_L2norm  \
# num_step
# 0                                     33.900273
# 1                                     31.828244
# 2                                     25.299374
# 3                                      9.416506
# 4                                      3.216534
#
#           layer_dict.linear.weights_weight_mean  \
# num_step
# 0                                     -0.001581
# 1                                     -0.001581
# 2                                     -0.001581
# 3                                     -0.001581
# 4                                     -0.001581
#
#           layer_dict.linear.weights_weight_L1norm  \
# num_step
# 0                                      227.932249
# 1                                      227.932167
# 2                                      228.560917
# 3                                      228.643100
# 4                                      228.748297
#
#           layer_dict.linear.weights_weight_L2norm  \
# num_step
# 0                                        5.061344
# 1                                        5.060931
# 2                                        5.065195
# 3                                        5.065944
# 4                                        5.066961
#
#           layer_dict.linear.bias_grad_mean  \
# num_step
# 0                             3.611610e-09
# 1                             7.866016e-10
# 2                             1.106244e-09
# 3                             9.073117e-10
# 4                             9.017504e-10
#
#           layer_dict.linear.bias_grad_L1norm  \
# num_step
# 0                                   1.536995
# 1                                   1.460804
# 2                                   1.173775
# 3                                   0.399003
# 4                                   0.124758
#
#           layer_dict.linear.bias_grad_L2norm  \
# num_step
# 0                                   0.858965
# 1                                   0.817055
# 2                                   0.660284
# 3                                   0.215315
# 4                                   0.067395
#
#           layer_dict.linear.bias_weight_mean  \
# num_step
# 0                                   0.010222
# 1                                   0.010222
# 2                                   0.010222
# 3                                   0.010222
# 4                                   0.010222
#
#           layer_dict.linear.bias_weight_L1norm  \
# num_step
# 0                                     0.774257
# 1                                     0.763789
# 2                                     0.756296
# 3                                     0.759681
# 4                                     0.759931
#
#           layer_dict.linear.bias_weight_L2norm
# num_step
# 0                                     0.369979
# 1                                     0.364852
# 2                                     0.361804
# 3                                     0.363281
# 4                                     0.363355
#
# [5 rows x 60 columns]

# %%
specific_column_values = norm_info_train[norm_info_train['num_step'] == 4]
specific_column_values
# Out:
#        current_iter  phase  num_step  layer_dict.conv0.conv.weight_grad_mean  \
# 4                 0  train         4                               -0.000306
# 9                 0  train         4                               -0.006918
# 14                1  train         4                                0.014745
# 19                1  train         4                                0.001461
# 24                2  train         4                                0.012580
# ...             ...    ...       ...                                     ...
# 796979        49997  train         4                                0.008004
# 796984        49998  train         4                               -0.001844
# 796989        49998  train         4                               -0.003642
# 796994        49999  train         4                                0.001570
# 796999        49999  train         4                               -0.000107
#
#         layer_dict.conv0.conv.weight_grad_L1norm  \
# 4                                      23.775303
# 9                                      50.483761
# 14                                     64.711731
# 19                                     54.244881
# 24                                     47.137360
# ...                                          ...
# 796979                                 21.781284
# 796984                                 28.377853
# 796989                                 13.766388
# 796994                                  7.705491
# 796999                                 24.990446
#
#         layer_dict.conv0.conv.weight_grad_L2norm  \
# 4                                       0.997047
# 9                                       2.430698
# 14                                      3.554599
# 19                                      2.498232
# 24                                      2.260482
# ...                                          ...
# 796979                                  1.009828
# 796984                                  1.150782
# 796989                                  0.602429
# 796994                                  0.301147
# 796999                                  1.022020
#
#         layer_dict.conv0.conv.weight_weight_mean  \
# 4                                      -0.001912
# 9                                      -0.001806
# 14                                     -0.001703
# 19                                     -0.002054
# 24                                     -0.001885
# ...                                          ...
# 796979                                 -0.000525
# 796984                                 -0.000121
# 796989                                  0.000057
# 796994                                  0.000012
# 796999                                 -0.000055
#
#         layer_dict.conv0.conv.weight_weight_L1norm  \
# 4                                        75.536194
# 9                                        75.527275
# 14                                       75.563385
# 19                                       75.574677
# 24                                       75.483688
# ...                                            ...
# 796979                                  243.589355
# 796984                                  243.562561
# 796989                                  243.623444
# 796994                                  243.535553
# 796999                                  243.565979
#
#         layer_dict.conv0.conv.weight_weight_L2norm  \
# 4                                         2.399853
# 9                                         2.401555
# 14                                        2.400829
# 19                                        2.401415
# 24                                        2.400533
# ...                                            ...
# 796979                                    8.443939
# 796984                                    8.443906
# 796989                                    8.444207
# 796994                                    8.443592
# 796999                                    8.444141
#
#         layer_dict.conv0.conv.bias_grad_mean  ...  \
# 4                              -2.483527e-09  ...
# 9                              -7.761022e-10  ...
# 14                             -1.901450e-08  ...
# 19                             -2.764864e-09  ...
# 24                              1.503698e-09  ...
# ...                                      ...  ...
# 796979                          9.428429e-10  ...
# 796984                          1.500666e-10  ...
# 796989                          4.241277e-10  ...
# 796994                         -3.368162e-10  ...
# 796999                          3.910827e-11  ...
#
#         layer_dict.linear.weights_grad_L2norm  \
# 4                                    0.867130
# 9                                    2.336724
# 14                                   2.009352
# 19                                   1.312641
# 24                                   1.291295
# ...                                       ...
# 796979                               4.870697
# 796984                               7.461635
# 796989                               2.910636
# 796994                               1.990393
# 796999                               3.713540
#
#         layer_dict.linear.weights_weight_mean  \
# 4                                   -0.000305
# 9                                   -0.000305
# 14                                  -0.000305
# 19                                  -0.000305
# 24                                  -0.000303
# ...                                       ...
# 796979                              -0.004014
# 796984                              -0.004015
# 796989                              -0.004015
# 796994                              -0.004017
# 796999                              -0.004017
#
#         layer_dict.linear.weights_weight_L1norm  \
# 4                                    211.859894
# 9                                    211.795593
# 14                                   211.629623
# 19                                   211.414215
# 24                                   211.493225
# ...                                         ...
# 796979                               472.714874
# 796984                               473.190430
# 796989                               473.328674
# 796994                               473.691711
# 796999                               473.394989
#
#         layer_dict.linear.weights_weight_L2norm  \
# 4                                      3.157067
# 9                                      3.156362
# 14                                     3.155667
# 19                                     3.153388
# 24                                     3.154287
# ...                                         ...
# 796979                                12.073843
# 796984                                12.074555
# 796989                                12.074634
# 796994                                12.076674
# 796999                                12.076173
#
#         layer_dict.linear.bias_grad_mean  layer_dict.linear.bias_grad_L1norm  \
# 4                          -7.450581e-10                            0.018554
# 9                          -4.097819e-09                            0.097012
# 14                         -1.722947e-09                            0.078322
# 19                          2.887100e-09                            0.022451
# 24                          2.235174e-09                            0.043084
# ...                                  ...                                 ...
# 796979                      3.725290e-10                            0.208027
# 796984                      0.000000e+00                            0.349022
# 796989                     -2.235174e-09                            0.127677
# 796994                      2.235174e-09                            0.075172
# 796999                     -2.980232e-09                            0.124371
#
#         layer_dict.linear.bias_grad_L2norm  \
# 4                                 0.010236
# 9                                 0.055859
# 14                                0.047334
# 19                                0.011024
# 24                                0.022486
# ...                                    ...
# 796979                            0.113210
# 796984                            0.165785
# 796989                            0.061769
# 796994                            0.038600
# 796999                            0.067839
#
#         layer_dict.linear.bias_weight_mean  \
# 4                            -9.313226e-11
# 9                            -2.328306e-11
# 14                           -1.999994e-04
# 19                           -1.999995e-04
# 24                           -2.960415e-04
# ...                                    ...
# 796979                        1.727822e-02
# 796984                        1.728085e-02
# 796989                        1.728084e-02
# 796994                        1.728333e-02
# 796999                        1.728334e-02
#
#         layer_dict.linear.bias_weight_L1norm  \
# 4                                   0.005389
# 9                                   0.004959
# 14                                  0.003246
# 19                                  0.005246
# 24                                  0.006578
# ...                                      ...
# 796979                              1.427202
# 796984                              1.427174
# 796989                              1.428258
# 796994                              1.424796
# 796999                              1.427426
#
#         layer_dict.linear.bias_weight_L2norm
# 4                                   0.002469
# 9                                   0.002334
# 14                                  0.001887
# 19                                  0.002761
# 24                                  0.003292
# ...                                      ...
# 796979                              0.669096
# 796984                              0.669096
# 796989                              0.669433
# 796994                              0.667881
# 796999                              0.669009
#
# [100000 rows x 63 columns]

# %%
gr = specific_column_values.groupby('current_iter').mean()

# %%
# 그래프를 그릴 컬럼들의 리스트
columns_to_plot = ['layer_dict.conv0.conv.weight_grad_L2norm', 
                   'layer_dict.conv1.conv.weight_grad_L2norm', 
                   'layer_dict.conv2.conv.weight_grad_L2norm',
                   'layer_dict.conv3.conv.weight_grad_L2norm',
                   'layer_dict.linear.weights_grad_L2norm']

columns_to_plot_label = ['conv1_w', 'conv2_w', 'conv3_w', 'conv4_w', 'classifier']

# 특정 열(Column)의 값을 그래프로 그리기
plt.figure(figsize=(10, 6))  # 그래프의 크기 설정 

plt.plot(gr[columns_to_plot].values, label=columns_to_plot_label)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), shadow=False, ncol=len(columns_to_plot))  # 범례 추가
plt.xlabel('Iteration')  # X 축 라벨 설정
plt.ylabel('Gradient Norm (log scale)')  

plt.yscale('log')  # Y 축을 로그 스케일로 변경
plt.ylim(10 ** -2, 10 **2)

plt.show()  # 그래프 보여주기

# %%
 # 그래프를 그릴 컬럼들의 리스트
columns_to_plot = [ 'layer_dict.conv0.conv.weight_weight_L2norm', 
                    'layer_dict.conv1.conv.weight_weight_L2norm', 
                    'layer_dict.conv2.conv.weight_weight_L2norm',
                    'layer_dict.conv3.conv.weight_weight_L2norm',
                    'layer_dict.linear.weights_weight_L2norm']
columns_to_plot_label = ['conv1_w', 'conv2_w', 'conv3_w', 'conv4_w', 'classifier']

# 특정 열(Column)의 값을 그래프로 그리기
plt.figure(figsize=(10, 6))  # 그래프의 크기 설정 

plt.plot(gr[columns_to_plot].values, label=columns_to_plot_label)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), shadow=False, ncol=len(columns_to_plot))  # 범례 추가
plt.ylabel('weight l2_norm')  

plt.show()  # 그래프 보여주기
