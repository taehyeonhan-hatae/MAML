# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
norm_info = pd.read_csv('../experiment_result/MAML_JM/MAML_JM.csv')
# Out:
# C:\Users\JM\anaconda3\envs\maml\lib\site-packages\IPython\core\interactiveshell.py:3553: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
norm_info_train= norm_info[norm_info['phase']=='train']
norm_info_val= norm_info[norm_info['phase']=='val']
norm_info_test= norm_info[norm_info['current_iter']=='test']

# %%
per_inner_loop_step = norm_info_train.groupby('num_step').mean()
per_inner_loop_step
# Out:
#           layer_dict.conv0.conv.weight_grad_mean  \
# num_step
# 0                                       0.021595
# 1                                      -0.002237
# 2                                      -0.007949
# 3                                       0.001539
# 4                                       0.000352
#
#           layer_dict.conv0.conv.weight_grad_L1norm  \
# num_step
# 0                                       220.981296
# 1                                        76.209986
# 2                                        71.616763
# 3                                        34.649019
# 4                                        15.733991
#
#           layer_dict.conv0.conv.weight_grad_L2norm  \
# num_step
# 0                                         9.856021
# 1                                         3.332791
# 2                                         3.168187
# 3                                         1.478192
# 4                                         0.669120
#
#           layer_dict.conv0.conv.weight_weight_mean  \
# num_step
# 0                                        -0.001655
# 1                                        -0.001633
# 2                                        -0.001553
# 3                                        -0.001569
# 4                                        -0.001572
#
#           layer_dict.conv0.conv.weight_weight_L1norm  \
# num_step
# 0                                         173.269547
# 1                                         173.273074
# 2                                         173.285424
# 3                                         173.283324
# 4                                         173.282978
#
#           layer_dict.conv0.conv.weight_weight_L2norm  \
# num_step
# 0                                           5.967738
# 1                                           5.967842
# 2                                           5.967946
# 3                                           5.967969
# 4                                           5.967975
#
#           layer_dict.conv0.conv.bias_grad_mean  \
# num_step
# 0                                 1.812621e-09
# 1                                 4.433622e-10
# 2                                 5.693263e-10
# 3                                -5.824541e-11
# 4                                -2.280185e-11
#
#           layer_dict.conv0.conv.bias_grad_L1norm  \
# num_step
# 0                                   1.726285e-06
# 1                                   1.095586e-06
# 2                                   8.973387e-07
# 3                                   3.467996e-07
# 4                                   1.638273e-07
#
#           layer_dict.conv0.conv.bias_grad_L2norm  \
# num_step
# 0                                   3.942696e-07
# 1                                   2.501274e-07
# 2                                   2.056305e-07
# 3                                   7.871433e-08
# 4                                   3.659030e-08
#
#           layer_dict.conv0.conv.bias_weight_mean  ...  \
# num_step                                          ...
# 0                                      -0.010689  ...
# 1                                      -0.010689  ...
# 2                                      -0.010689  ...
# 3                                      -0.010689  ...
# 4                                      -0.010689  ...
#
#           layer_dict.linear.weights_grad_L2norm  \
# num_step
# 0                                     33.900273
# 1                                     31.828244
# 2                                     25.299374
# 3                                      9.416506
# 4                                      3.216534
#
#           layer_dict.linear.weights_weight_mean  \
# num_step
# 0                                     -0.001581
# 1                                     -0.001581
# 2                                     -0.001581
# 3                                     -0.001581
# 4                                     -0.001581
#
#           layer_dict.linear.weights_weight_L1norm  \
# num_step
# 0                                      227.932249
# 1                                      227.932167
# 2                                      228.560917
# 3                                      228.643100
# 4                                      228.748297
#
#           layer_dict.linear.weights_weight_L2norm  \
# num_step
# 0                                        5.061344
# 1                                        5.060931
# 2                                        5.065195
# 3                                        5.065944
# 4                                        5.066961
#
#           layer_dict.linear.bias_grad_mean  \
# num_step
# 0                             3.611610e-09
# 1                             7.866016e-10
# 2                             1.106244e-09
# 3                             9.073117e-10
# 4                             9.017504e-10
#
#           layer_dict.linear.bias_grad_L1norm  \
# num_step
# 0                                   1.536995
# 1                                   1.460804
# 2                                   1.173775
# 3                                   0.399003
# 4                                   0.124758
#
#           layer_dict.linear.bias_grad_L2norm  \
# num_step
# 0                                   0.858965
# 1                                   0.817055
# 2                                   0.660284
# 3                                   0.215315
# 4                                   0.067395
#
#           layer_dict.linear.bias_weight_mean  \
# num_step
# 0                                   0.010222
# 1                                   0.010222
# 2                                   0.010222
# 3                                   0.010222
# 4                                   0.010222
#
#           layer_dict.linear.bias_weight_L1norm  \
# num_step
# 0                                     0.774257
# 1                                     0.763789
# 2                                     0.756296
# 3                                     0.759681
# 4                                     0.759931
#
#           layer_dict.linear.bias_weight_L2norm
# num_step
# 0                                     0.369979
# 1                                     0.364852
# 2                                     0.361804
# 3                                     0.363281
# 4                                     0.363355
#
# [5 rows x 60 columns]

# %%
per_inner_loop_step['layer_dict.linear.weights_grad_L2norm']
# Out:
# num_step
# 0    33.900273
# 1    31.828244
# 2    25.299374
# 3     9.416506
# 4     3.216534
# Name: layer_dict.linear.weights_grad_L2norm, dtype: float64

# %%
per_inner_loop_step['layer_dict.conv3.conv.weight_grad_L2norm']
# Out:
# num_step
# 0    2.110491
# 1    1.124088
# 2    1.043178
# 3    0.512092
# 4    0.228309
# Name: layer_dict.conv3.conv.weight_grad_L2norm, dtype: float64

# %%
per_inner_loop_step['layer_dict.conv3.conv.weight_weight_L2norm']
# Out:
# num_step
# 0    21.029750
# 1    21.029754
# 2    21.029758
# 3    21.029759
# 4    21.029759
# Name: layer_dict.conv3.conv.weight_weight_L2norm, dtype: float64

# %%
per_inner_loop_step['layer_dict.linear.weights_weight_L2norm']
# Out:
# num_step
# 0    5.061344
# 1    5.060931
# 2    5.065195
# 3    5.065944
# 4    5.066961
# Name: layer_dict.linear.weights_weight_L2norm, dtype: float64

# %%
specific_column_values = norm_info_train[norm_info_train['num_step'] == 0]
specific_column_values
# Out:
#        current_iter  phase  num_step  layer_dict.conv0.conv.weight_grad_mean  \
# 0                 0  train         0                                0.013776
# 5                 0  train         0                                0.003947
# 10                1  train         0                               -0.032375
# 15                1  train         0                                0.006516
# 20                2  train         0                                0.002183
# ...             ...    ...       ...                                     ...
# 796975        49997  train         0                               -0.028673
# 796980        49998  train         0                               -0.080934
# 796985        49998  train         0                               -0.098372
# 796990        49999  train         0                               -0.064136
# 796995        49999  train         0                               -0.101110
#
#         layer_dict.conv0.conv.weight_grad_L1norm  \
# 0                                     238.842392
# 5                                     237.155334
# 10                                    213.720200
# 15                                    263.778168
# 20                                    198.301239
# ...                                          ...
# 796975                                283.517670
# 796980                                263.352417
# 796985                                308.510986
# 796990                                200.892578
# 796995                                273.956451
#
#         layer_dict.conv0.conv.weight_grad_L2norm  \
# 0                                      10.310260
# 5                                      10.745303
# 10                                      9.032267
# 15                                     10.384514
# 20                                      7.739654
# ...                                          ...
# 796975                                 12.320526
# 796980                                 11.839870
# 796985                                 13.315084
# 796990                                  8.576903
# 796995                                 12.355079
#
#         layer_dict.conv0.conv.weight_weight_mean  \
# 0                                      -0.001893
# 5                                      -0.001794
# 10                                     -0.001442
# 15                                     -0.001831
# 20                                     -0.001774
# ...                                          ...
# 796975                                 -0.000257
# 796980                                  0.000264
# 796985                                  0.000438
# 796990                                  0.000109
# 796995                                  0.000479
#
#         layer_dict.conv0.conv.weight_weight_L1norm  \
# 0                                        75.503906
# 5                                        75.466515
# 10                                       75.534904
# 15                                       75.523987
# 20                                       75.455208
# ...                                            ...
# 796975                                  243.510818
# 796980                                  243.612549
# 796985                                  243.583130
# 796990                                  243.563599
# 796995                                  243.560684
#
#         layer_dict.conv0.conv.weight_weight_L2norm  \
# 0                                         2.398884
# 5                                         2.399075
# 10                                        2.399027
# 15                                        2.399574
# 20                                        2.398928
# ...                                            ...
# 796975                                    8.443750
# 796980                                    8.443772
# 796985                                    8.443993
# 796990                                    8.443516
# 796995                                    8.443983
#
#         layer_dict.conv0.conv.bias_grad_mean  ...  \
# 0                               2.933666e-08  ...
# 5                               4.028940e-08  ...
# 10                             -9.158006e-09  ...
# 15                              4.450946e-08  ...
# 20                             -1.552204e-08  ...
# ...                                      ...  ...
# 796975                          1.171551e-08  ...
# 796980                         -7.397224e-09  ...
# 796985                         -4.045432e-09  ...
# 796990                          3.378470e-09  ...
# 796995                          3.280972e-08  ...
#
#         layer_dict.linear.weights_grad_L2norm  \
# 0                                   10.609147
# 5                                    8.282177
# 10                                   9.009080
# 15                                   9.424679
# 20                                   8.400191
# ...                                       ...
# 796975                              38.629135
# 796980                              38.547310
# 796985                              38.460659
# 796990                              38.105633
# 796995                              38.652901
#
#         layer_dict.linear.weights_weight_mean  \
# 0                                   -0.000305
# 5                                   -0.000305
# 10                                  -0.000305
# 15                                  -0.000305
# 20                                  -0.000303
# ...                                       ...
# 796975                              -0.004014
# 796980                              -0.004015
# 796985                              -0.004015
# 796990                              -0.004017
# 796995                              -0.004017
#
#         layer_dict.linear.weights_weight_L1norm  \
# 0                                    211.443634
# 5                                    211.384125
# 10                                   211.314819
# 15                                   211.166656
# 20                                   211.177750
# ...                                         ...
# 796975                               471.842987
# 796980                               471.965240
# 796985                               472.155182
# 796990                               472.245544
# 796995                               472.104431
#
#         layer_dict.linear.weights_weight_L2norm  \
# 0                                      3.151407
# 5                                      3.150550
# 10                                     3.149549
# 15                                     3.147862
# 20                                     3.148209
# ...                                         ...
# 796975                                12.071321
# 796980                                12.072056
# 796985                                12.072106
# 796990                                12.073503
# 796995                                12.073324
#
#         layer_dict.linear.bias_grad_mean  layer_dict.linear.bias_grad_L1norm  \
# 0                           1.490116e-09                            0.498336
# 5                           5.960465e-09                            0.428868
# 10                          2.980232e-09                            0.461648
# 15                          5.960465e-09                            0.430484
# 20                         -2.980232e-09                            0.519055
# ...                                  ...                                 ...
# 796975                      1.192093e-08                            1.599936
# 796980                      0.000000e+00                            1.599880
# 796985                      1.192093e-08                            1.599936
# 796990                      1.192093e-08                            1.599884
# 796995                      0.000000e+00                            1.599876
#
#         layer_dict.linear.bias_grad_L2norm  \
# 0                                 0.275611
# 5                                 0.228195
# 10                                0.222072
# 15                                0.234765
# 20                                0.255557
# ...                                    ...
# 796975                            0.894392
# 796980                            0.894360
# 796985                            0.894392
# 796990                            0.894362
# 796995                            0.894358
#
#         layer_dict.linear.bias_weight_mean  \
# 0                             1.164153e-11
# 5                            -3.492460e-11
# 10                           -1.999994e-04
# 15                           -1.999994e-04
# 20                           -2.960414e-04
# ...                                    ...
# 796975                        1.727823e-02
# 796980                        1.728084e-02
# 796985                        1.728084e-02
# 796990                        1.728334e-02
# 796995                        1.728334e-02
#
#         layer_dict.linear.bias_weight_L1norm  \
# 0                                   0.004983
# 5                                   0.004289
# 10                                  0.005616
# 15                                  0.004936
# 20                                  0.007385
# ...                                      ...
# 796975                              1.442483
# 796980                              1.442172
# 796985                              1.442172
# 796990                              1.442215
# 796995                              1.442215
#
#         layer_dict.linear.bias_weight_L2norm
# 0                                   0.002756
# 5                                   0.002282
# 10                                  0.003018
# 15                                  0.002620
# 20                                  0.004054
# ...                                      ...
# 796975                              0.675592
# 796980                              0.675419
# 796985                              0.675419
# 796990                              0.675415
# 796995                              0.675415
#
# [100000 rows x 63 columns]

# %%
gr = specific_column_values.groupby('current_iter').mean()

# %%
# 그래프를 그릴 컬럼들의 리스트
columns_to_plot = ['layer_dict.conv0.conv.weight_grad_L2norm', 
                   'layer_dict.conv1.conv.weight_grad_L2norm', 
                   'layer_dict.conv2.conv.weight_grad_L2norm',
                   'layer_dict.conv3.conv.weight_grad_L2norm',
                   'layer_dict.linear.weights_grad_L2norm']

columns_to_plot_label = ['conv1_w', 'conv2_w', 'conv3_w', 'conv4_w', 'classifier']

# 특정 열(Column)의 값을 그래프로 그리기
plt.figure(figsize=(10, 6))  # 그래프의 크기 설정 

plt.plot(gr[columns_to_plot].values, label=columns_to_plot_label)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), shadow=False, ncol=len(columns_to_plot))  # 범례 추가
plt.xlabel('Iteration')  # X 축 라벨 설정
plt.ylabel('Gradient Norm (log scale)')  

plt.yscale('log')  # Y 축을 로그 스케일로 변경
plt.ylim(10 ** -2, 10 **2)

plt.show()  # 그래프 보여주기

# %%
 # 그래프를 그릴 컬럼들의 리스트
columns_to_plot = [ 'layer_dict.conv0.conv.weight_weight_L2norm', 
                    'layer_dict.conv1.conv.weight_weight_L2norm', 
                    'layer_dict.conv2.conv.weight_weight_L2norm',
                    'layer_dict.conv3.conv.weight_weight_L2norm',
                    'layer_dict.linear.weights_weight_L2norm']
columns_to_plot_label = ['conv1_w', 'conv2_w', 'conv3_w', 'conv4_w', 'classifier']

# 특정 열(Column)의 값을 그래프로 그리기
plt.figure(figsize=(10, 6))  # 그래프의 크기 설정 

plt.plot(gr[columns_to_plot].values, label=columns_to_plot_label)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), shadow=False, ncol=len(columns_to_plot))  # 범례 추가
plt.ylabel('weight l2_norm')  

plt.show()  # 그래프 보여주기
