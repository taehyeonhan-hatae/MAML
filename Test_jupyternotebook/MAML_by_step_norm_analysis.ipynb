# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
norm_info = pd.read_csv('../experiment_result/MAML_JM/MAML_JM.csv')
# Out:
# C:\Users\JM\anaconda3\envs\maml\lib\site-packages\IPython\core\interactiveshell.py:3553: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
norm_info_train= norm_info[norm_info['phase']=='train']
norm_info_val= norm_info[norm_info['phase']=='val']
norm_info_test= norm_info[norm_info['current_iter']=='test']

# %%
per_inner_loop_step = norm_info_train.groupby('num_step').mean()
per_inner_loop_step
# Out:
#           layer_dict.conv0.conv.weight_grad_mean  \
# num_step
# 0                                       0.021595
# 1                                      -0.002237
# 2                                      -0.007949
# 3                                       0.001539
# 4                                       0.000352
#
#           layer_dict.conv0.conv.weight_grad_L1norm  \
# num_step
# 0                                       220.981296
# 1                                        76.209986
# 2                                        71.616763
# 3                                        34.649019
# 4                                        15.733991
#
#           layer_dict.conv0.conv.weight_grad_L2norm  \
# num_step
# 0                                         9.856021
# 1                                         3.332791
# 2                                         3.168187
# 3                                         1.478192
# 4                                         0.669120
#
#           layer_dict.conv0.conv.weight_weight_mean  \
# num_step
# 0                                        -0.001655
# 1                                        -0.001633
# 2                                        -0.001553
# 3                                        -0.001569
# 4                                        -0.001572
#
#           layer_dict.conv0.conv.weight_weight_L1norm  \
# num_step
# 0                                         173.269547
# 1                                         173.273074
# 2                                         173.285424
# 3                                         173.283324
# 4                                         173.282978
#
#           layer_dict.conv0.conv.weight_weight_L2norm  \
# num_step
# 0                                           5.967738
# 1                                           5.967842
# 2                                           5.967946
# 3                                           5.967969
# 4                                           5.967975
#
#           layer_dict.conv0.conv.bias_grad_mean  \
# num_step
# 0                                 1.812621e-09
# 1                                 4.433622e-10
# 2                                 5.693263e-10
# 3                                -5.824541e-11
# 4                                -2.280185e-11
#
#           layer_dict.conv0.conv.bias_grad_L1norm  \
# num_step
# 0                                   1.726285e-06
# 1                                   1.095586e-06
# 2                                   8.973387e-07
# 3                                   3.467996e-07
# 4                                   1.638273e-07
#
#           layer_dict.conv0.conv.bias_grad_L2norm  \
# num_step
# 0                                   3.942696e-07
# 1                                   2.501274e-07
# 2                                   2.056305e-07
# 3                                   7.871433e-08
# 4                                   3.659030e-08
#
#           layer_dict.conv0.conv.bias_weight_mean  ...  \
# num_step                                          ...
# 0                                      -0.010689  ...
# 1                                      -0.010689  ...
# 2                                      -0.010689  ...
# 3                                      -0.010689  ...
# 4                                      -0.010689  ...
#
#           layer_dict.linear.weights_grad_L2norm  \
# num_step
# 0                                     33.900273
# 1                                     31.828244
# 2                                     25.299374
# 3                                      9.416506
# 4                                      3.216534
#
#           layer_dict.linear.weights_weight_mean  \
# num_step
# 0                                     -0.001581
# 1                                     -0.001581
# 2                                     -0.001581
# 3                                     -0.001581
# 4                                     -0.001581
#
#           layer_dict.linear.weights_weight_L1norm  \
# num_step
# 0                                      227.932249
# 1                                      227.932167
# 2                                      228.560917
# 3                                      228.643100
# 4                                      228.748297
#
#           layer_dict.linear.weights_weight_L2norm  \
# num_step
# 0                                        5.061344
# 1                                        5.060931
# 2                                        5.065195
# 3                                        5.065944
# 4                                        5.066961
#
#           layer_dict.linear.bias_grad_mean  \
# num_step
# 0                             3.611610e-09
# 1                             7.866016e-10
# 2                             1.106244e-09
# 3                             9.073117e-10
# 4                             9.017504e-10
#
#           layer_dict.linear.bias_grad_L1norm  \
# num_step
# 0                                   1.536995
# 1                                   1.460804
# 2                                   1.173775
# 3                                   0.399003
# 4                                   0.124758
#
#           layer_dict.linear.bias_grad_L2norm  \
# num_step
# 0                                   0.858965
# 1                                   0.817055
# 2                                   0.660284
# 3                                   0.215315
# 4                                   0.067395
#
#           layer_dict.linear.bias_weight_mean  \
# num_step
# 0                                   0.010222
# 1                                   0.010222
# 2                                   0.010222
# 3                                   0.010222
# 4                                   0.010222
#
#           layer_dict.linear.bias_weight_L1norm  \
# num_step
# 0                                     0.774257
# 1                                     0.763789
# 2                                     0.756296
# 3                                     0.759681
# 4                                     0.759931
#
#           layer_dict.linear.bias_weight_L2norm
# num_step
# 0                                     0.369979
# 1                                     0.364852
# 2                                     0.361804
# 3                                     0.363281
# 4                                     0.363355
#
# [5 rows x 60 columns]

# %%
plt.figure(figsize=(8, 6))
norm_info_train.boxplot(column='layer_dict.linear.weights_grad_L2norm', by='num_step')
plt.title('inner loop step')
plt.xlabel('step')
plt.ylabel('classifer gradient norm')
plt.suptitle('')  # 기본 제목 제거
plt.show()

# %%
plt.figure(figsize=(8, 6))
norm_info_train.boxplot(column='layer_dict.linear.weights_weight_L2norm', by='num_step')
plt.title('inner loop step')
plt.xlabel('step')
plt.ylabel('layer_dict.linear.weights_weight_L2norm')
plt.suptitle('')  # 기본 제목 제거
plt.show()

# %%
plt.figure(figsize=(8, 6))
norm_info_train.boxplot(column='layer_dict.conv3.conv.weight_weight_L2norm', by='num_step')
plt.title('inner loop step')
plt.xlabel('step')
plt.ylabel('layer_dict.conv0.conv.weight_weight_L2norm')
plt.suptitle('')  # 기본 제목 제거
plt.show()

# %%
plt.figure(figsize=(8, 6))
norm_info_train.boxplot(column='layer_dict.conv3.conv.weight_grad_L2norm', by='num_step')
plt.title('inner loop step')
plt.xlabel('step')
plt.ylabel('layer_dict.conv3.conv.weight_grad_L2norm')
plt.suptitle('')  # 기본 제목 제거
plt.show()
